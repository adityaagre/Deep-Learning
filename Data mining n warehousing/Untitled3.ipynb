# %%
## DMW A1: Data Preprocessing
## Aditya Agre TYCOA6

## Data set : movies.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('business-financial-data-june-2023-quarter-csv.csv')
df
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 6910     BDCQ.SF8RSCA  2022.06     579.955        NaN      F  Dollars
# 6911     BDCQ.SF8RSCA  2022.09     609.161        NaN      F  Dollars
# 6912     BDCQ.SF8RSCA  2022.12     518.615        NaN      F  Dollars
# 6913     BDCQ.SF8RSCA  2023.03     663.630        NaN      F  Dollars
# 6914     BDCQ.SF8RSCA  2023.06     617.507        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# 1             6  Business Data Collection - BDC
# 2             6  Business Data Collection - BDC
# 3             6  Business Data Collection - BDC
# 4             6  Business Data Collection - BDC
# ...         ...                             ...
# 6910          6  Business Data Collection - BDC
# 6911          6  Business Data Collection - BDC
# 6912          6  Business Data Collection - BDC
# 6913          6  Business Data Collection - BDC
# 6914          6  Business Data Collection - BDC
#
#                                                 Group  \
# 0     Industry by financial variable (NZSIOC Level 2)
# 1     Industry by financial variable (NZSIOC Level 2)
# 2     Industry by financial variable (NZSIOC Level 2)
# 3     Industry by financial variable (NZSIOC Level 2)
# 4     Industry by financial variable (NZSIOC Level 2)
# ...                                               ...
# 6910  Industry by financial variable (NZSIOC Level 1)
# 6911  Industry by financial variable (NZSIOC Level 1)
# 6912  Industry by financial variable (NZSIOC Level 1)
# 6913  Industry by financial variable (NZSIOC Level 1)
# 6914  Industry by financial variable (NZSIOC Level 1)
#
#                 Series_title_1                       Series_title_2  \
# 0     Sales (operating income)                 Forestry and Logging
# 1     Sales (operating income)                 Forestry and Logging
# 2     Sales (operating income)                 Forestry and Logging
# 3     Sales (operating income)                 Forestry and Logging
# 4     Sales (operating income)                 Forestry and Logging
# ...                        ...                                  ...
# 6910          Operating profit  Arts, Recreation and Other Services
# 6911          Operating profit  Arts, Recreation and Other Services
# 6912          Operating profit  Arts, Recreation and Other Services
# 6913          Operating profit  Arts, Recreation and Other Services
# 6914          Operating profit  Arts, Recreation and Other Services
#
#       Series_title_3 Series_title_4  Series_title_5
# 0     Current prices     Unadjusted             NaN
# 1     Current prices     Unadjusted             NaN
# 2     Current prices     Unadjusted             NaN
# 3     Current prices     Unadjusted             NaN
# 4     Current prices     Unadjusted             NaN
# ...              ...            ...             ...
# 6910         Current     Unadjusted             NaN
# 6911         Current     Unadjusted             NaN
# 6912         Current     Unadjusted             NaN
# 6913         Current     Unadjusted             NaN
# 6914         Current     Unadjusted             NaN
#
# [6915 rows x 14 columns]

# %%
## 5) Going through all measures of central tendency

# %%
## Studying modal values per column
df.mode(axis = 0)
# Out:
#     Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0      BDCQ.SF1AA2CA  2017.09     847.349          Y      F  Dollars
# 1      BDCQ.SF1AA2CS  2017.12     925.547        NaN    NaN      NaN
# 2      BDCQ.SF1AA2CT  2018.03    1040.500        NaN    NaN      NaN
# 3      BDCQ.SF1AA3CA  2018.06    1063.775        NaN    NaN      NaN
# 4      BDCQ.SF1AA3CS  2018.09    1077.447        NaN    NaN      NaN
# ..               ...      ...         ...        ...    ...      ...
# 226    BDCQ.SF8QQ1CA      NaN         NaN        NaN    NaN      NaN
# 227     BDCQ.SF8QQCA      NaN         NaN        NaN    NaN      NaN
# 228    BDCQ.SF8RS1CA      NaN         NaN        NaN    NaN      NaN
# 229    BDCQ.SF8RS2CA      NaN         NaN        NaN    NaN      NaN
# 230     BDCQ.SF8RSCA      NaN         NaN        NaN    NaN      NaN
#
#      Magnitude                         Subject  \
# 0          6.0  Business Data Collection - BDC
# 1          NaN                             NaN
# 2          NaN                             NaN
# 3          NaN                             NaN
# 4          NaN                             NaN
# ..         ...                             ...
# 226        NaN                             NaN
# 227        NaN                             NaN
# 228        NaN                             NaN
# 229        NaN                             NaN
# 230        NaN                             NaN
#
#                                                Group  \
# 0    Industry by financial variable (NZSIOC Level 2)
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 226                                              NaN
# 227                                              NaN
# 228                                              NaN
# 229                                              NaN
# 230                                              NaN
#
#                Series_title_1                              Series_title_2  \
# 0    Sales (operating income)                                Construction
# 1                         NaN                      Education and Training
# 2                         NaN  Electricity, Gas, Water and Waste Services
# 3                         NaN           Health Care and Social Assistance
# 4                         NaN    Information Media and Telecommunications
# ..                        ...                                         ...
# 226                       NaN                                         NaN
# 227                       NaN                                         NaN
# 228                       NaN                                         NaN
# 229                       NaN                                         NaN
# 230                       NaN                                         NaN
#
#      Series_title_3 Series_title_4  Series_title_5
# 0    Current prices     Unadjusted             NaN
# 1               NaN            NaN             NaN
# 2               NaN            NaN             NaN
# 3               NaN            NaN             NaN
# 4               NaN            NaN             NaN
# ..              ...            ...             ...
# 226             NaN            NaN             NaN
# 227             NaN            NaN             NaN
# 228             NaN            NaN             NaN
# 229             NaN            NaN             NaN
# 230             NaN            NaN             NaN
#
# [231 rows x 14 columns]

# %%
## Studying mean values per column
df.mean()
# Out:
# /var/folders/ft/m0h88bl55gl0qmgjxz9qczfc0000gn/T/ipykernel_55282/2762134590.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Period            2019.473197
# Data_value        4826.080308
# Magnitude            6.000000
# Series_title_5            NaN
# dtype: float64

# %%
## Studying median values per column
df.median()
# Out:
# /var/folders/ft/m0h88bl55gl0qmgjxz9qczfc0000gn/T/ipykernel_55282/1669262333.py:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Period            2019.1200
# Data_value        2118.3655
# Magnitude            6.0000
# Series_title_5          NaN
# dtype: float64

# %%
## Handling Missing Values

# %%
## which of these columns have null values

no_of_col = df.shape[1]

for i in range(no_of_col):
    if(df[:i].isnull().values.any()):
        print("Col ",i," has null values.")
# Out:
# Col  1  has null values.
# Col  2  has null values.
# Col  3  has null values.
# Col  4  has null values.
# Col  5  has null values.
# Col  6  has null values.
# Col  7  has null values.
# Col  8  has null values.
# Col  9  has null values.
# Col  10  has null values.
# Col  11  has null values.
# Col  12  has null values.
# Col  13  has null values.

# %%
## Checking number of null entries per column.
df.isnull().sum()
# Out:
# Series_reference       0
# Period                 0
# Data_value           605
# Suppressed          6870
# STATUS                 0
# UNITS                  0
# Magnitude              0
# Subject                0
# Group                  0
# Series_title_1         0
# Series_title_2         0
# Series_title_3         0
# Series_title_4         0
# Series_title_5      6915
# dtype: int64

# %%
null_col = []
for col in df:
    
    ## print(col)
    null_col.append(col)
    
null_col

for col in null_col:
    df[col] = df[col].fillna(df[col].mode())
df
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386          Y      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 6910     BDCQ.SF8RSCA  2022.06     579.955        NaN      F  Dollars
# 6911     BDCQ.SF8RSCA  2022.09     609.161        NaN      F  Dollars
# 6912     BDCQ.SF8RSCA  2022.12     518.615        NaN      F  Dollars
# 6913     BDCQ.SF8RSCA  2023.03     663.630        NaN      F  Dollars
# 6914     BDCQ.SF8RSCA  2023.06     617.507        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# 1             6  Business Data Collection - BDC
# 2             6  Business Data Collection - BDC
# 3             6  Business Data Collection - BDC
# 4             6  Business Data Collection - BDC
# ...         ...                             ...
# 6910          6  Business Data Collection - BDC
# 6911          6  Business Data Collection - BDC
# 6912          6  Business Data Collection - BDC
# 6913          6  Business Data Collection - BDC
# 6914          6  Business Data Collection - BDC
#
#                                                 Group  \
# 0     Industry by financial variable (NZSIOC Level 2)
# 1     Industry by financial variable (NZSIOC Level 2)
# 2     Industry by financial variable (NZSIOC Level 2)
# 3     Industry by financial variable (NZSIOC Level 2)
# 4     Industry by financial variable (NZSIOC Level 2)
# ...                                               ...
# 6910  Industry by financial variable (NZSIOC Level 1)
# 6911  Industry by financial variable (NZSIOC Level 1)
# 6912  Industry by financial variable (NZSIOC Level 1)
# 6913  Industry by financial variable (NZSIOC Level 1)
# 6914  Industry by financial variable (NZSIOC Level 1)
#
#                 Series_title_1                       Series_title_2  \
# 0     Sales (operating income)                 Forestry and Logging
# 1     Sales (operating income)                 Forestry and Logging
# 2     Sales (operating income)                 Forestry and Logging
# 3     Sales (operating income)                 Forestry and Logging
# 4     Sales (operating income)                 Forestry and Logging
# ...                        ...                                  ...
# 6910          Operating profit  Arts, Recreation and Other Services
# 6911          Operating profit  Arts, Recreation and Other Services
# 6912          Operating profit  Arts, Recreation and Other Services
# 6913          Operating profit  Arts, Recreation and Other Services
# 6914          Operating profit  Arts, Recreation and Other Services
#
#       Series_title_3 Series_title_4  Series_title_5
# 0     Current prices     Unadjusted             NaN
# 1     Current prices     Unadjusted             NaN
# 2     Current prices     Unadjusted             NaN
# 3     Current prices     Unadjusted             NaN
# 4     Current prices     Unadjusted             NaN
# ...              ...            ...             ...
# 6910         Current     Unadjusted             NaN
# 6911         Current     Unadjusted             NaN
# 6912         Current     Unadjusted             NaN
# 6913         Current     Unadjusted             NaN
# 6914         Current     Unadjusted             NaN
#
# [6915 rows x 14 columns]

# %%
## Checking number of null entries per column.
df.isnull().sum()
# Out:
# Series_reference       0
# Period                 0
# Data_value           591
# Suppressed          6869
# STATUS                 0
# UNITS                  0
# Magnitude              0
# Subject                0
# Group                  0
# Series_title_1         0
# Series_title_2         0
# Series_title_3         0
# Series_title_4         0
# Series_title_5      6915
# dtype: int64

# %%
df
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386          Y      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 6910     BDCQ.SF8RSCA  2022.06     579.955        NaN      F  Dollars
# 6911     BDCQ.SF8RSCA  2022.09     609.161        NaN      F  Dollars
# 6912     BDCQ.SF8RSCA  2022.12     518.615        NaN      F  Dollars
# 6913     BDCQ.SF8RSCA  2023.03     663.630        NaN      F  Dollars
# 6914     BDCQ.SF8RSCA  2023.06     617.507        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# 1             6  Business Data Collection - BDC
# 2             6  Business Data Collection - BDC
# 3             6  Business Data Collection - BDC
# 4             6  Business Data Collection - BDC
# ...         ...                             ...
# 6910          6  Business Data Collection - BDC
# 6911          6  Business Data Collection - BDC
# 6912          6  Business Data Collection - BDC
# 6913          6  Business Data Collection - BDC
# 6914          6  Business Data Collection - BDC
#
#                                                 Group  \
# 0     Industry by financial variable (NZSIOC Level 2)
# 1     Industry by financial variable (NZSIOC Level 2)
# 2     Industry by financial variable (NZSIOC Level 2)
# 3     Industry by financial variable (NZSIOC Level 2)
# 4     Industry by financial variable (NZSIOC Level 2)
# ...                                               ...
# 6910  Industry by financial variable (NZSIOC Level 1)
# 6911  Industry by financial variable (NZSIOC Level 1)
# 6912  Industry by financial variable (NZSIOC Level 1)
# 6913  Industry by financial variable (NZSIOC Level 1)
# 6914  Industry by financial variable (NZSIOC Level 1)
#
#                 Series_title_1                       Series_title_2  \
# 0     Sales (operating income)                 Forestry and Logging
# 1     Sales (operating income)                 Forestry and Logging
# 2     Sales (operating income)                 Forestry and Logging
# 3     Sales (operating income)                 Forestry and Logging
# 4     Sales (operating income)                 Forestry and Logging
# ...                        ...                                  ...
# 6910          Operating profit  Arts, Recreation and Other Services
# 6911          Operating profit  Arts, Recreation and Other Services
# 6912          Operating profit  Arts, Recreation and Other Services
# 6913          Operating profit  Arts, Recreation and Other Services
# 6914          Operating profit  Arts, Recreation and Other Services
#
#       Series_title_3 Series_title_4  Series_title_5
# 0     Current prices     Unadjusted             NaN
# 1     Current prices     Unadjusted             NaN
# 2     Current prices     Unadjusted             NaN
# 3     Current prices     Unadjusted             NaN
# 4     Current prices     Unadjusted             NaN
# ...              ...            ...             ...
# 6910         Current     Unadjusted             NaN
# 6911         Current     Unadjusted             NaN
# 6912         Current     Unadjusted             NaN
# 6913         Current     Unadjusted             NaN
# 6914         Current     Unadjusted             NaN
#
# [6915 rows x 14 columns]

# %%
df['Data_value'].replace(np.NaN, df['Data_value'].mode()[0],inplace=True)
df
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386          Y      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 6910     BDCQ.SF8RSCA  2022.06     579.955        NaN      F  Dollars
# 6911     BDCQ.SF8RSCA  2022.09     609.161        NaN      F  Dollars
# 6912     BDCQ.SF8RSCA  2022.12     518.615        NaN      F  Dollars
# 6913     BDCQ.SF8RSCA  2023.03     663.630        NaN      F  Dollars
# 6914     BDCQ.SF8RSCA  2023.06     617.507        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# 1             6  Business Data Collection - BDC
# 2             6  Business Data Collection - BDC
# 3             6  Business Data Collection - BDC
# 4             6  Business Data Collection - BDC
# ...         ...                             ...
# 6910          6  Business Data Collection - BDC
# 6911          6  Business Data Collection - BDC
# 6912          6  Business Data Collection - BDC
# 6913          6  Business Data Collection - BDC
# 6914          6  Business Data Collection - BDC
#
#                                                 Group  \
# 0     Industry by financial variable (NZSIOC Level 2)
# 1     Industry by financial variable (NZSIOC Level 2)
# 2     Industry by financial variable (NZSIOC Level 2)
# 3     Industry by financial variable (NZSIOC Level 2)
# 4     Industry by financial variable (NZSIOC Level 2)
# ...                                               ...
# 6910  Industry by financial variable (NZSIOC Level 1)
# 6911  Industry by financial variable (NZSIOC Level 1)
# 6912  Industry by financial variable (NZSIOC Level 1)
# 6913  Industry by financial variable (NZSIOC Level 1)
# 6914  Industry by financial variable (NZSIOC Level 1)
#
#                 Series_title_1                       Series_title_2  \
# 0     Sales (operating income)                 Forestry and Logging
# 1     Sales (operating income)                 Forestry and Logging
# 2     Sales (operating income)                 Forestry and Logging
# 3     Sales (operating income)                 Forestry and Logging
# 4     Sales (operating income)                 Forestry and Logging
# ...                        ...                                  ...
# 6910          Operating profit  Arts, Recreation and Other Services
# 6911          Operating profit  Arts, Recreation and Other Services
# 6912          Operating profit  Arts, Recreation and Other Services
# 6913          Operating profit  Arts, Recreation and Other Services
# 6914          Operating profit  Arts, Recreation and Other Services
#
#       Series_title_3 Series_title_4  Series_title_5
# 0     Current prices     Unadjusted             NaN
# 1     Current prices     Unadjusted             NaN
# 2     Current prices     Unadjusted             NaN
# 3     Current prices     Unadjusted             NaN
# 4     Current prices     Unadjusted             NaN
# ...              ...            ...             ...
# 6910         Current     Unadjusted             NaN
# 6911         Current     Unadjusted             NaN
# 6912         Current     Unadjusted             NaN
# 6913         Current     Unadjusted             NaN
# 6914         Current     Unadjusted             NaN
#
# [6915 rows x 14 columns]

# %%
# Lets look at the duplicate rows now
df[df.duplicated(keep='first')]
# Removing these rows
df.drop_duplicates(keep='first', inplace=True)
df
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386          Y      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 6910     BDCQ.SF8RSCA  2022.06     579.955        NaN      F  Dollars
# 6911     BDCQ.SF8RSCA  2022.09     609.161        NaN      F  Dollars
# 6912     BDCQ.SF8RSCA  2022.12     518.615        NaN      F  Dollars
# 6913     BDCQ.SF8RSCA  2023.03     663.630        NaN      F  Dollars
# 6914     BDCQ.SF8RSCA  2023.06     617.507        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# 1             6  Business Data Collection - BDC
# 2             6  Business Data Collection - BDC
# 3             6  Business Data Collection - BDC
# 4             6  Business Data Collection - BDC
# ...         ...                             ...
# 6910          6  Business Data Collection - BDC
# 6911          6  Business Data Collection - BDC
# 6912          6  Business Data Collection - BDC
# 6913          6  Business Data Collection - BDC
# 6914          6  Business Data Collection - BDC
#
#                                                 Group  \
# 0     Industry by financial variable (NZSIOC Level 2)
# 1     Industry by financial variable (NZSIOC Level 2)
# 2     Industry by financial variable (NZSIOC Level 2)
# 3     Industry by financial variable (NZSIOC Level 2)
# 4     Industry by financial variable (NZSIOC Level 2)
# ...                                               ...
# 6910  Industry by financial variable (NZSIOC Level 1)
# 6911  Industry by financial variable (NZSIOC Level 1)
# 6912  Industry by financial variable (NZSIOC Level 1)
# 6913  Industry by financial variable (NZSIOC Level 1)
# 6914  Industry by financial variable (NZSIOC Level 1)
#
#                 Series_title_1                       Series_title_2  \
# 0     Sales (operating income)                 Forestry and Logging
# 1     Sales (operating income)                 Forestry and Logging
# 2     Sales (operating income)                 Forestry and Logging
# 3     Sales (operating income)                 Forestry and Logging
# 4     Sales (operating income)                 Forestry and Logging
# ...                        ...                                  ...
# 6910          Operating profit  Arts, Recreation and Other Services
# 6911          Operating profit  Arts, Recreation and Other Services
# 6912          Operating profit  Arts, Recreation and Other Services
# 6913          Operating profit  Arts, Recreation and Other Services
# 6914          Operating profit  Arts, Recreation and Other Services
#
#       Series_title_3 Series_title_4  Series_title_5
# 0     Current prices     Unadjusted             NaN
# 1     Current prices     Unadjusted             NaN
# 2     Current prices     Unadjusted             NaN
# 3     Current prices     Unadjusted             NaN
# 4     Current prices     Unadjusted             NaN
# ...              ...            ...             ...
# 6910         Current     Unadjusted             NaN
# 6911         Current     Unadjusted             NaN
# 6912         Current     Unadjusted             NaN
# 6913         Current     Unadjusted             NaN
# 6914         Current     Unadjusted             NaN
#
# [6915 rows x 14 columns]

# %%
## data has not been arranged according to any pattern
## Yet, we are shuffling 

df = df.sample(frac=1, random_state=42)
df
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 5219     BDCQ.SF3FFCA  2019.12    2069.680        NaN      F  Dollars
# 828     BDCQ.SF1CC5CS  2020.06    3413.355        NaN      R  Dollars
# 3269    BDCQ.SF1RS1CS  2021.09    1299.285        NaN      R  Dollars
# 1433     BDCQ.SF1DDCS  2019.06    5296.602        NaN      R  Dollars
# 4937    BDCQ.SF3CC6CA  2021.12     201.206        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 3772    BDCQ.SF2CC6CA  2016.12     620.816        NaN      F  Dollars
# 5191    BDCQ.SF3FF1CA  2020.03    1954.248        NaN      F  Dollars
# 5226     BDCQ.SF3FFCA  2021.09    2165.344        NaN      F  Dollars
# 5390    BDCQ.SF3JJ1CA  2022.12     688.216        NaN      F  Dollars
# 860     BDCQ.SF1CC5CT  2021.03    5165.815        NaN      C  Dollars
#
#       Magnitude                         Subject  \
# 5219          6  Business Data Collection - BDC
# 828           6  Business Data Collection - BDC
# 3269          6  Business Data Collection - BDC
# 1433          6  Business Data Collection - BDC
# 4937          6  Business Data Collection - BDC
# ...         ...                             ...
# 3772          6  Business Data Collection - BDC
# 5191          6  Business Data Collection - BDC
# 5226          6  Business Data Collection - BDC
# 5390          6  Business Data Collection - BDC
# 860           6  Business Data Collection - BDC
#
#                                                 Group  \
# 5219  Industry by financial variable (NZSIOC Level 1)
# 828   Industry by financial variable (NZSIOC Level 2)
# 3269  Industry by financial variable (NZSIOC Level 2)
# 1433  Industry by financial variable (NZSIOC Level 1)
# 4937  Industry by financial variable (NZSIOC Level 2)
# ...                                               ...
# 3772  Industry by financial variable (NZSIOC Level 2)
# 5191  Industry by financial variable (NZSIOC Level 2)
# 5226  Industry by financial variable (NZSIOC Level 1)
# 5390  Industry by financial variable (NZSIOC Level 2)
# 860   Industry by financial variable (NZSIOC Level 2)
#
#                            Series_title_1  \
# 5219                   Salaries and wages
# 828              Sales (operating income)
# 3269             Sales (operating income)
# 1433             Sales (operating income)
# 4937                   Salaries and wages
# ...                                   ...
# 3772  Purchases and operating expenditure
# 5191                   Salaries and wages
# 5226                   Salaries and wages
# 5390                   Salaries and wages
# 860              Sales (operating income)
#
#                                          Series_title_2  Series_title_3  \
# 5219                                    Wholesale Trade         Current
# 828   Petroleum, Chemical, Polymer and Rubber Produc...  Current prices
# 3269                       Arts and Recreation Services  Current prices
# 1433         Electricity, Gas, Water and Waste Services         Current
# 4937         Non-Metallic Mineral Product Manufacturing  Current prices
# ...                                                 ...             ...
# 3772         Non-Metallic Mineral Product Manufacturing  Current prices
# 5191                                    Wholesale Trade  Current prices
# 5226                                    Wholesale Trade         Current
# 5390           Information Media and Telecommunications  Current prices
# 860   Petroleum, Chemical, Polymer and Rubber Produc...  Current prices
#
#            Series_title_4  Series_title_5
# 5219           Unadjusted             NaN
# 828   Seasonally adjusted             NaN
# 3269  Seasonally adjusted             NaN
# 1433  Seasonally adjusted             NaN
# 4937           Unadjusted             NaN
# ...                   ...             ...
# 3772           Unadjusted             NaN
# 5191           Unadjusted             NaN
# 5226           Unadjusted             NaN
# 5390           Unadjusted             NaN
# 860                 Trend             NaN
#
# [6915 rows x 14 columns]

# %%
## Normalising Data using min max scaling
## PLotting histogram

df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Period'}>,
#         <AxesSubplot:title={'center':'Data_value'}>],
#        [<AxesSubplot:title={'center':'Magnitude'}>,
#         <AxesSubplot:title={'center':'Series_title_5'}>]], dtype=object)

# %%
## Plotting boxplot

df.boxplot()
# Out:
# <AxesSubplot:>

# %%
# Boxplot shows many outliers

# lets make a general func that removes outliers for a given column

def outlier_remove(col_i):
    ## Lets follow inter quartile range method
    ## return the values of the lower range limit and upper range limit
    ## these limits have values 1.5*(inter quartile range beyond) first and third quartiles.
    
    ## To find quartiles, we must sort the column
    sorted(col_i)
    print(col_i)
    
    Q1,Q3 = np.percentile(col_i , [25,75]) 
    ## because we are taking quartiles. therefore 25% and 75%
    inter_q_range = Q3-Q1
    
    l_lim = Q1 - (1.5 * inter_q_range)
    up_lim = Q3 + (1.5 * inter_q_range)
    return l_lim,up_lim

# %%
l,u=outlier_remove(df.Data_value)
print(l,u,q1,q3,iqr)

rows = df.shape[0]

df.drop(df[(df.Data_value < l) | (df.Data_value > u)].index,inplace=True)
# Out:
# 5219    2069.680
# 828     3413.355
# 3269    1299.285
# 1433    5296.602
# 4937     201.206
#           ...
# 3772     620.816
# 5191    1954.248
# 5226    2165.344
# 5390     688.216
# 860     5165.815
# Name: Data_value, Length: 6915, dtype: float64
# -5928.416249999998 11822.353749999998 nan nan nan

# %%
l,u=outlier_remove(df.Data_value)
print(l,u,q1,q3,iqr)

rows = df.shape[0]

df.drop(df[(df.Data_value < l) | (df.Data_value > u)].index,inplace=True)
# Out:
# 5219    2069.680
# 828     3413.355
# 3269    1299.285
# 1433    5296.602
# 4937     201.206
#           ...
# 3772     620.816
# 5191    1954.248
# 5226    2165.344
# 5390     688.216
# 860     5165.815
# Name: Data_value, Length: 6108, dtype: float64
# -4733.8478749999995 9570.571124999999 nan nan nan

# %%
l,u=outlier_remove(df.Data_value)
print(l,u,q1,q3,iqr)

rows = df.shape[0]

df.drop(df[(df.Data_value < l) | (df.Data_value > u)].index,inplace=True)
# Out:
# 5219    2069.680
# 828     3413.355
# 3269    1299.285
# 1433    5296.602
# 4937     201.206
#           ...
# 3772     620.816
# 5191    1954.248
# 5226    2165.344
# 5390     688.216
# 860     5165.815
# Name: Data_value, Length: 6003, dtype: float64
# -4514.4527499999995 9174.881249999999 nan nan nan

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
## Outliers removed

# %%
from sklearn.preprocessing import MinMaxScaler

MMscaler = MinMaxScaler()
## We have created an object of minmax scaler class

# %%
df_ncol= df.select_dtypes(exclude=['object'])
df_ncol
## We are doing this to extract onlythe numeric cols
## A new dataframe is being created with just these cols
# Out:
#         Period  Data_value  Magnitude  Series_title_5
# 5219  0.437143    0.258364        0.0             NaN
# 828   0.571429    0.399034        0.0             NaN
# 3269  0.718571    0.177710        0.0             NaN
# 1433  0.428571    0.596193        0.0             NaN
# 4937  0.722857    0.062752        0.0             NaN
# ...        ...         ...        ...             ...
# 3772  0.008571    0.106681        0.0             NaN
# 5191  0.567143    0.246279        0.0             NaN
# 5226  0.718571    0.268379        0.0             NaN
# 5390  0.865714    0.113737        0.0             NaN
# 860   0.710000    0.582500        0.0             NaN
#
# [5986 rows x 4 columns]

# %%
## Making a copy of df
temp = df

# Scalable columns
cols= df_ncol.columns

## Performing min max scalning
temp[cols]=  MMscaler.fit_transform(df[cols])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:473: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:474: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)

# %%
temp
# Out:
#      Series_reference    Period  Data_value Suppressed STATUS    UNITS  \
# 5219     BDCQ.SF3FFCA  0.437143    0.258364        NaN      F  Dollars
# 828     BDCQ.SF1CC5CS  0.571429    0.399034        NaN      R  Dollars
# 3269    BDCQ.SF1RS1CS  0.718571    0.177710        NaN      R  Dollars
# 1433     BDCQ.SF1DDCS  0.428571    0.596193        NaN      R  Dollars
# 4937    BDCQ.SF3CC6CA  0.722857    0.062752        NaN      F  Dollars
# ...               ...       ...         ...        ...    ...      ...
# 3772    BDCQ.SF2CC6CA  0.008571    0.106681        NaN      F  Dollars
# 5191    BDCQ.SF3FF1CA  0.567143    0.246279        NaN      F  Dollars
# 5226     BDCQ.SF3FFCA  0.718571    0.268379        NaN      F  Dollars
# 5390    BDCQ.SF3JJ1CA  0.865714    0.113737        NaN      F  Dollars
# 860     BDCQ.SF1CC5CT  0.710000    0.582500        NaN      C  Dollars
#
#       Magnitude                         Subject  \
# 5219        0.0  Business Data Collection - BDC
# 828         0.0  Business Data Collection - BDC
# 3269        0.0  Business Data Collection - BDC
# 1433        0.0  Business Data Collection - BDC
# 4937        0.0  Business Data Collection - BDC
# ...         ...                             ...
# 3772        0.0  Business Data Collection - BDC
# 5191        0.0  Business Data Collection - BDC
# 5226        0.0  Business Data Collection - BDC
# 5390        0.0  Business Data Collection - BDC
# 860         0.0  Business Data Collection - BDC
#
#                                                 Group  \
# 5219  Industry by financial variable (NZSIOC Level 1)
# 828   Industry by financial variable (NZSIOC Level 2)
# 3269  Industry by financial variable (NZSIOC Level 2)
# 1433  Industry by financial variable (NZSIOC Level 1)
# 4937  Industry by financial variable (NZSIOC Level 2)
# ...                                               ...
# 3772  Industry by financial variable (NZSIOC Level 2)
# 5191  Industry by financial variable (NZSIOC Level 2)
# 5226  Industry by financial variable (NZSIOC Level 1)
# 5390  Industry by financial variable (NZSIOC Level 2)
# 860   Industry by financial variable (NZSIOC Level 2)
#
#                            Series_title_1  \
# 5219                   Salaries and wages
# 828              Sales (operating income)
# 3269             Sales (operating income)
# 1433             Sales (operating income)
# 4937                   Salaries and wages
# ...                                   ...
# 3772  Purchases and operating expenditure
# 5191                   Salaries and wages
# 5226                   Salaries and wages
# 5390                   Salaries and wages
# 860              Sales (operating income)
#
#                                          Series_title_2  Series_title_3  \
# 5219                                    Wholesale Trade         Current
# 828   Petroleum, Chemical, Polymer and Rubber Produc...  Current prices
# 3269                       Arts and Recreation Services  Current prices
# 1433         Electricity, Gas, Water and Waste Services         Current
# 4937         Non-Metallic Mineral Product Manufacturing  Current prices
# ...                                                 ...             ...
# 3772         Non-Metallic Mineral Product Manufacturing  Current prices
# 5191                                    Wholesale Trade  Current prices
# 5226                                    Wholesale Trade         Current
# 5390           Information Media and Telecommunications  Current prices
# 860   Petroleum, Chemical, Polymer and Rubber Produc...  Current prices
#
#            Series_title_4  Series_title_5
# 5219           Unadjusted             NaN
# 828   Seasonally adjusted             NaN
# 3269  Seasonally adjusted             NaN
# 1433  Seasonally adjusted             NaN
# 4937           Unadjusted             NaN
# ...                   ...             ...
# 3772           Unadjusted             NaN
# 5191           Unadjusted             NaN
# 5226           Unadjusted             NaN
# 5390           Unadjusted             NaN
# 860                 Trend             NaN
#
# [5986 rows x 14 columns]

# %%
## Columns scaled using min max scaling
