# %%
## Aditya Agre
## 121B1B006
## Honors IE2

# %%
####### Reference: #######
## https://attyuttam.medium.com/generative-adversarial-networks-using-pytorch-3ad31cc61ac8
## https://www.jovian.ai/ Exact notebook?
#########################

# %%
import os

import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import FashionMNIST

#Load the data

mnist = FashionMNIST(root='data', 
              train=True, 
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))

# %%
# Viewing the data

img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  9
# tensor([[[-1.0000, -1.0000, -1.0000,  0.5137,  0.7882],
#          [-0.9765, -1.0000, -0.9059,  0.7176,  0.7255],
#          [-0.9529, -1.0000, -0.2235,  0.9137,  0.7412],
#          [-1.0000, -1.0000, -0.5686,  0.8510,  0.7882],
#          [-1.0000, -1.0000,  0.8588,  0.7725,  0.7020]]])
# (tensor(-1.), tensor(1.))

# %%
# When viewing the images we would like to de normalize it 
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
# View the image on screen

import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 9

# %%
from torch.utils.data import DataLoader

#To ensure that the data is loaded in batches during training we are using a DataLoader. 

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
# In this block we are trying to print all the images in a batch
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([1, 1, 3, 5, 6, 4, 8, 1, 2, 1, 0, 5, 5, 7, 1, 9, 2, 2, 6, 8, 1, 6, 4, 7,
#         5, 3, 7, 9, 0, 1, 5, 7, 5, 8, 1, 2, 1, 2, 5, 2, 6, 5, 1, 4, 7, 4, 7, 4,
#         2, 6, 6, 0, 1, 5, 8, 1, 4, 9, 7, 5, 0, 4, 8, 1, 1, 0, 5, 4, 2, 1, 9, 3,
#         7, 9, 2, 2, 5, 4, 7, 3, 2, 1, 7, 1, 8, 0, 0, 0, 4, 8, 1, 0, 3, 3, 9, 5,
#         2, 6, 4, 5])

# %%
image_size = 784
hidden_size = 256
latent_size = 64

# %%
import torch.nn as nn

# Define a pretty simple Disriminator network which has:
# 1. Linear layer which takes in an input of image_size as 784 and hidden size 256
# 2. The output of the linear layer is passed through a ReLU activation function
# 3. The result of the activation function is then passed through a Linear layer which takes in 256 input and produces 256 outputs
# 4. This result is again passed through a leaky relu layer.
# 5. Finally the output is passed through a Linear layer and the result is passed through the sigmoid function.

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %%
# Define a pretty simple Generator network which has:
# 1. Linear layer which takes in an input of image_size as 64 and hidden size 256
# 2. The output of the linear layer is passed through a ReLU activation function
# 3. The result of the activation function is then passed through a Linear layer which takes in 256 input and produces 256 outputs
# 4. This result is again passed through a leaky relu layer.
# 5. Finally the output is passed through a Linear layer and the result is passed through the tanh() function.

G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %%
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %%
# Training the discriminator

def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images, d_loss_old=-1):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1) # .to(device)
    fake_labels = torch.zeros(batch_size, 1) # .to(device)
        
    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size) # .to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs
    
    # So essentially, you use the given set of real images and feed it to the discriminator and train to understand the pattern of the real images.
    # Then, you generate a bunch of fake images and then feed them to the discriminator to train them to understand the pattern of the fake images.

    # Combine losses
    d_loss = d_loss_real + d_loss_fake

    # # Reset gradients
    # reset_grad()
    # # Compute gradients
    # d_loss.backward()
    # # Adjust the parameters using backprop
    # d_optimizer.step()
    # print(d_loss.item(), d_loss_old, d_loss.item() > d_loss_old)
    if d_loss.item() > d_loss_old:
    # if d_loss_old == -1 or d_loss > d_loss_old:
        # Reset gradients
        reset_grad()
        # Compute gradients
        d_loss.backward()
        # Adjust the parameters using backprop
        d_optimizer.step()

    return d_loss, real_score, fake_score

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator(g_loss_old=-1):
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size) # .to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1)  # .to(device)
    g_loss = criterion(D(fake_images), labels)

    # # Backprop and optimize
    # reset_grad()
    # g_loss.backward()
    # g_optimizer.step()
    # print(g_loss)
    # print(g_loss.item(), g_loss_old, g_loss.item() > g_loss_old)
    if g_loss.item() > g_loss_old:
    # if g_loss_old == -1 or g_loss > g_loss_old:
        # Backprop and optimize
        reset_grad()
        g_loss.backward()
        g_optimizer.step()
        
    return g_loss, fake_images

# %%
### For GAN ###
sample_dir = 'samples_fmnist_gan'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break
   
Image(os.path.join(sample_dir, 'real_images.png'))

# %%
sample_vectors = torch.randn(batch_size, latent_size) # .to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)
    
# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %%
# %%time

### GAN training ###
num_epochs = 300
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1)  # .to(device)
        
        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        d_losses.append(d_loss.item())
        g_losses.append(g_loss.item())
        real_scores.append(real_score.mean().item())
        fake_scores.append(fake_score.mean().item())
        
    print('Epoch [{}/{}],  d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
          .format(epoch, num_epochs, d_loss.item(), g_loss.item(), 
                  real_score.mean().item(), fake_score.mean().item()))        
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300],  d_loss: 0.0418, g_loss: 5.1111, D(x): 0.98, D(G(z)): 0.02
# Saving fake_images-0001.png
# Epoch [1/300],  d_loss: 0.0216, g_loss: 5.4410, D(x): 0.99, D(G(z)): 0.01
# Saving fake_images-0002.png
# Epoch [2/300],  d_loss: 0.0202, g_loss: 7.3495, D(x): 0.99, D(G(z)): 0.00
# Saving fake_images-0003.png
# Epoch [3/300],  d_loss: 0.0364, g_loss: 7.7140, D(x): 1.00, D(G(z)): 0.03
# Saving fake_images-0004.png
# Epoch [4/300],  d_loss: 0.1221, g_loss: 9.0981, D(x): 0.97, D(G(z)): 0.00
# Saving fake_images-0005.png
# Epoch [5/300],  d_loss: 0.0640, g_loss: 5.9472, D(x): 0.98, D(G(z)): 0.03
# Saving fake_images-0006.png
# Epoch [6/300],  d_loss: 0.0794, g_loss: 5.7419, D(x): 0.97, D(G(z)): 0.02
# Saving fake_images-0007.png
# Epoch [7/300],  d_loss: 0.2007, g_loss: 5.9445, D(x): 0.95, D(G(z)): 0.08
# Saving fake_images-0008.png
# Epoch [8/300],  d_loss: 0.1968, g_loss: 5.1134, D(x): 0.94, D(G(z)): 0.04
# Saving fake_images-0009.png
# Epoch [9/300],  d_loss: 0.3474, g_loss: 4.7151, D(x): 0.92, D(G(z)): 0.10
# Saving fake_images-0010.png
# Epoch [10/300],  d_loss: 0.2847, g_loss: 5.2623, D(x): 0.89, D(G(z)): 0.03
# Saving fake_images-0011.png
# Epoch [11/300],  d_loss: 0.2299, g_loss: 5.0470, D(x): 0.94, D(G(z)): 0.08
# Saving fake_images-0012.png
# Epoch [12/300],  d_loss: 0.4639, g_loss: 3.5031, D(x): 0.88, D(G(z)): 0.08
# Saving fake_images-0013.png
# Epoch [13/300],  d_loss: 0.6709, g_loss: 4.5939, D(x): 0.78, D(G(z)): 0.03
# Saving fake_images-0014.png
# Epoch [14/300],  d_loss: 0.3491, g_loss: 3.8738, D(x): 0.89, D(G(z)): 0.08
# Saving fake_images-0015.png
# Epoch [15/300],  d_loss: 0.3321, g_loss: 3.1276, D(x): 0.93, D(G(z)): 0.17
# Saving fake_images-0016.png
# Epoch [16/300],  d_loss: 0.4122, g_loss: 2.6800, D(x): 0.88, D(G(z)): 0.12
# Saving fake_images-0017.png
# Epoch [17/300],  d_loss: 0.3547, g_loss: 4.2404, D(x): 0.87, D(G(z)): 0.09
# Saving fake_images-0018.png
# Epoch [18/300],  d_loss: 0.5560, g_loss: 2.9170, D(x): 0.90, D(G(z)): 0.23
# Saving fake_images-0019.png
# Epoch [19/300],  d_loss: 0.4874, g_loss: 2.2815, D(x): 0.87, D(G(z)): 0.19
# Saving fake_images-0020.png
# Epoch [20/300],  d_loss: 0.6550, g_loss: 2.7801, D(x): 0.79, D(G(z)): 0.09
# Saving fake_images-0021.png
# Epoch [21/300],  d_loss: 0.3936, g_loss: 2.8846, D(x): 0.90, D(G(z)): 0.17
# Saving fake_images-0022.png
# Epoch [22/300],  d_loss: 0.4473, g_loss: 3.4581, D(x): 0.88, D(G(z)): 0.16
# Saving fake_images-0023.png
# Epoch [23/300],  d_loss: 0.5628, g_loss: 2.9885, D(x): 0.80, D(G(z)): 0.12
# Saving fake_images-0024.png
# Epoch [24/300],  d_loss: 0.6327, g_loss: 2.2527, D(x): 0.83, D(G(z)): 0.22
# Saving fake_images-0025.png
# Epoch [25/300],  d_loss: 0.5744, g_loss: 2.7042, D(x): 0.85, D(G(z)): 0.17
# Saving fake_images-0026.png
# Epoch [26/300],  d_loss: 0.4143, g_loss: 3.2075, D(x): 0.85, D(G(z)): 0.10
# Saving fake_images-0027.png
# Epoch [27/300],  d_loss: 0.5082, g_loss: 3.7196, D(x): 0.82, D(G(z)): 0.10
# Saving fake_images-0028.png
# Epoch [28/300],  d_loss: 0.6340, g_loss: 2.7723, D(x): 0.85, D(G(z)): 0.20
# Saving fake_images-0029.png
# Epoch [29/300],  d_loss: 0.5690, g_loss: 2.6686, D(x): 0.83, D(G(z)): 0.17
# Saving fake_images-0030.png
# Epoch [30/300],  d_loss: 0.4320, g_loss: 3.9343, D(x): 0.94, D(G(z)): 0.19
# Saving fake_images-0031.png
# Epoch [31/300],  d_loss: 0.6806, g_loss: 2.7380, D(x): 0.82, D(G(z)): 0.15
# Saving fake_images-0032.png
# Epoch [32/300],  d_loss: 0.6158, g_loss: 3.1491, D(x): 0.80, D(G(z)): 0.11
# Saving fake_images-0033.png
# Epoch [33/300],  d_loss: 0.5370, g_loss: 3.2232, D(x): 0.80, D(G(z)): 0.12
# Saving fake_images-0034.png
# Epoch [34/300],  d_loss: 0.6526, g_loss: 3.0492, D(x): 0.87, D(G(z)): 0.24
# Saving fake_images-0035.png
# Epoch [35/300],  d_loss: 0.7542, g_loss: 2.7470, D(x): 0.74, D(G(z)): 0.13
# Saving fake_images-0036.png
# Epoch [36/300],  d_loss: 0.5103, g_loss: 2.6462, D(x): 0.85, D(G(z)): 0.17
# Saving fake_images-0037.png
# Epoch [37/300],  d_loss: 0.9295, g_loss: 2.7540, D(x): 0.71, D(G(z)): 0.18
# Saving fake_images-0038.png
# Epoch [38/300],  d_loss: 0.4274, g_loss: 2.6298, D(x): 0.84, D(G(z)): 0.15
# Saving fake_images-0039.png
# Epoch [39/300],  d_loss: 0.4992, g_loss: 1.8685, D(x): 0.84, D(G(z)): 0.15
# Saving fake_images-0040.png
# Epoch [40/300],  d_loss: 0.8913, g_loss: 2.0475, D(x): 0.80, D(G(z)): 0.29
# Saving fake_images-0041.png
# Epoch [41/300],  d_loss: 0.4104, g_loss: 2.3773, D(x): 0.87, D(G(z)): 0.15
# Saving fake_images-0042.png
# Epoch [42/300],  d_loss: 0.6508, g_loss: 2.3148, D(x): 0.88, D(G(z)): 0.31
# Saving fake_images-0043.png
# Epoch [43/300],  d_loss: 0.6606, g_loss: 2.0800, D(x): 0.77, D(G(z)): 0.15
# Saving fake_images-0044.png
# Epoch [44/300],  d_loss: 0.5269, g_loss: 3.3843, D(x): 0.83, D(G(z)): 0.15
# Saving fake_images-0045.png
# Epoch [45/300],  d_loss: 0.6002, g_loss: 2.5263, D(x): 0.80, D(G(z)): 0.14
# Saving fake_images-0046.png
# Epoch [46/300],  d_loss: 0.5807, g_loss: 3.3093, D(x): 0.77, D(G(z)): 0.09
# Saving fake_images-0047.png
# Epoch [47/300],  d_loss: 0.6281, g_loss: 2.7964, D(x): 0.87, D(G(z)): 0.27
# Saving fake_images-0048.png
# Epoch [48/300],  d_loss: 1.1195, g_loss: 2.1492, D(x): 0.71, D(G(z)): 0.27
# Saving fake_images-0049.png
# Epoch [49/300],  d_loss: 0.6472, g_loss: 2.5292, D(x): 0.83, D(G(z)): 0.24
# Saving fake_images-0050.png
# Epoch [50/300],  d_loss: 0.6464, g_loss: 2.5222, D(x): 0.80, D(G(z)): 0.18
# Saving fake_images-0051.png
# Epoch [51/300],  d_loss: 0.4203, g_loss: 2.9314, D(x): 0.86, D(G(z)): 0.14
# Saving fake_images-0052.png
# Epoch [52/300],  d_loss: 0.8165, g_loss: 2.3947, D(x): 0.78, D(G(z)): 0.23
# Saving fake_images-0053.png
# Epoch [53/300],  d_loss: 0.7354, g_loss: 2.6752, D(x): 0.80, D(G(z)): 0.27
# Saving fake_images-0054.png
# Epoch [54/300],  d_loss: 0.8285, g_loss: 2.5491, D(x): 0.74, D(G(z)): 0.19
# Saving fake_images-0055.png
# Epoch [55/300],  d_loss: 0.7661, g_loss: 2.3204, D(x): 0.80, D(G(z)): 0.24
# Saving fake_images-0056.png
# Epoch [56/300],  d_loss: 0.7288, g_loss: 1.5913, D(x): 0.84, D(G(z)): 0.33
# Saving fake_images-0057.png
# Epoch [57/300],  d_loss: 0.6354, g_loss: 1.8370, D(x): 0.83, D(G(z)): 0.26
# Saving fake_images-0058.png
# Epoch [58/300],  d_loss: 0.7087, g_loss: 2.0309, D(x): 0.81, D(G(z)): 0.25
# Saving fake_images-0059.png
# Epoch [59/300],  d_loss: 0.8079, g_loss: 2.0863, D(x): 0.74, D(G(z)): 0.21
# Saving fake_images-0060.png
# Epoch [60/300],  d_loss: 0.6711, g_loss: 1.9406, D(x): 0.75, D(G(z)): 0.18
# Saving fake_images-0061.png
# Epoch [61/300],  d_loss: 0.6147, g_loss: 2.5806, D(x): 0.76, D(G(z)): 0.12
# Saving fake_images-0062.png
# Epoch [62/300],  d_loss: 0.8745, g_loss: 2.1481, D(x): 0.75, D(G(z)): 0.24
# Saving fake_images-0063.png
# Epoch [63/300],  d_loss: 0.7065, g_loss: 2.5835, D(x): 0.75, D(G(z)): 0.16
# Saving fake_images-0064.png
# Epoch [64/300],  d_loss: 0.7341, g_loss: 2.8136, D(x): 0.72, D(G(z)): 0.12
# Saving fake_images-0065.png
# Epoch [65/300],  d_loss: 0.7042, g_loss: 2.5770, D(x): 0.76, D(G(z)): 0.15
# Saving fake_images-0066.png
# Epoch [66/300],  d_loss: 0.7480, g_loss: 1.9583, D(x): 0.79, D(G(z)): 0.23
# Saving fake_images-0067.png
# Epoch [67/300],  d_loss: 0.7264, g_loss: 2.0712, D(x): 0.79, D(G(z)): 0.25
# Saving fake_images-0068.png
# Epoch [68/300],  d_loss: 0.6711, g_loss: 2.5907, D(x): 0.79, D(G(z)): 0.23
# Saving fake_images-0069.png
# Epoch [69/300],  d_loss: 0.4687, g_loss: 2.2140, D(x): 0.83, D(G(z)): 0.15
# Saving fake_images-0070.png
# Epoch [70/300],  d_loss: 0.7878, g_loss: 2.5561, D(x): 0.75, D(G(z)): 0.23
# Saving fake_images-0071.png
# Epoch [71/300],  d_loss: 0.6304, g_loss: 3.4000, D(x): 0.78, D(G(z)): 0.15
# Saving fake_images-0072.png
# Epoch [72/300],  d_loss: 0.8003, g_loss: 1.7676, D(x): 0.78, D(G(z)): 0.33
# Saving fake_images-0073.png
# Epoch [73/300],  d_loss: 0.9618, g_loss: 2.5882, D(x): 0.69, D(G(z)): 0.21
# Saving fake_images-0074.png
# Epoch [74/300],  d_loss: 0.7813, g_loss: 1.8369, D(x): 0.79, D(G(z)): 0.29
# Saving fake_images-0075.png
# Epoch [75/300],  d_loss: 0.7307, g_loss: 2.6204, D(x): 0.76, D(G(z)): 0.22
# Saving fake_images-0076.png
# Epoch [76/300],  d_loss: 0.7875, g_loss: 1.9868, D(x): 0.78, D(G(z)): 0.26
# Saving fake_images-0077.png
# Epoch [77/300],  d_loss: 0.8553, g_loss: 1.6228, D(x): 0.76, D(G(z)): 0.29
# Saving fake_images-0078.png
# Epoch [78/300],  d_loss: 0.7722, g_loss: 2.0871, D(x): 0.80, D(G(z)): 0.31
# Saving fake_images-0079.png
# Epoch [79/300],  d_loss: 0.5689, g_loss: 2.1576, D(x): 0.81, D(G(z)): 0.20
# Saving fake_images-0080.png
# Epoch [80/300],  d_loss: 0.8490, g_loss: 1.8724, D(x): 0.76, D(G(z)): 0.29
# Saving fake_images-0081.png
# Epoch [81/300],  d_loss: 0.9855, g_loss: 1.5392, D(x): 0.68, D(G(z)): 0.29
# Saving fake_images-0082.png
# Epoch [82/300],  d_loss: 0.7640, g_loss: 2.0286, D(x): 0.75, D(G(z)): 0.24
# Saving fake_images-0083.png
# Epoch [83/300],  d_loss: 0.7995, g_loss: 1.7040, D(x): 0.72, D(G(z)): 0.26
# Saving fake_images-0084.png
# Epoch [84/300],  d_loss: 1.0695, g_loss: 1.9008, D(x): 0.74, D(G(z)): 0.36
# Saving fake_images-0085.png
# Epoch [85/300],  d_loss: 0.8021, g_loss: 1.9481, D(x): 0.75, D(G(z)): 0.26
# Saving fake_images-0086.png
# Epoch [86/300],  d_loss: 0.8957, g_loss: 1.4733, D(x): 0.77, D(G(z)): 0.37
# Saving fake_images-0087.png
# Epoch [87/300],  d_loss: 0.5536, g_loss: 2.6835, D(x): 0.80, D(G(z)): 0.14
# Saving fake_images-0088.png
# Epoch [88/300],  d_loss: 0.6274, g_loss: 2.2883, D(x): 0.78, D(G(z)): 0.21
# Saving fake_images-0089.png
# Epoch [89/300],  d_loss: 0.8125, g_loss: 1.8713, D(x): 0.68, D(G(z)): 0.20
# Saving fake_images-0090.png
# Epoch [90/300],  d_loss: 0.7650, g_loss: 2.1645, D(x): 0.83, D(G(z)): 0.34
# Saving fake_images-0091.png
# Epoch [91/300],  d_loss: 0.6114, g_loss: 2.2691, D(x): 0.84, D(G(z)): 0.24
# Saving fake_images-0092.png
# Epoch [92/300],  d_loss: 0.7323, g_loss: 2.3243, D(x): 0.77, D(G(z)): 0.22
# Saving fake_images-0093.png
# Epoch [93/300],  d_loss: 1.1367, g_loss: 2.1518, D(x): 0.60, D(G(z)): 0.23
# Saving fake_images-0094.png
# Epoch [94/300],  d_loss: 0.8468, g_loss: 1.8836, D(x): 0.71, D(G(z)): 0.22
# Saving fake_images-0095.png
# Epoch [95/300],  d_loss: 0.8336, g_loss: 1.7244, D(x): 0.73, D(G(z)): 0.26
# Saving fake_images-0096.png
# Epoch [96/300],  d_loss: 0.8574, g_loss: 1.9374, D(x): 0.69, D(G(z)): 0.22
# Saving fake_images-0097.png
# Epoch [97/300],  d_loss: 0.6797, g_loss: 2.1287, D(x): 0.79, D(G(z)): 0.26
# Saving fake_images-0098.png
# Epoch [98/300],  d_loss: 0.7355, g_loss: 2.1282, D(x): 0.81, D(G(z)): 0.29
# Saving fake_images-0099.png
# Epoch [99/300],  d_loss: 0.5151, g_loss: 1.9567, D(x): 0.84, D(G(z)): 0.22
# Saving fake_images-0100.png
# Epoch [100/300],  d_loss: 0.8208, g_loss: 1.5952, D(x): 0.75, D(G(z)): 0.27
# Saving fake_images-0101.png
# Epoch [101/300],  d_loss: 1.1187, g_loss: 1.8714, D(x): 0.62, D(G(z)): 0.27
# Saving fake_images-0102.png
# Epoch [102/300],  d_loss: 0.7512, g_loss: 1.8217, D(x): 0.71, D(G(z)): 0.21
# Saving fake_images-0103.png
# Epoch [103/300],  d_loss: 0.8205, g_loss: 1.8142, D(x): 0.75, D(G(z)): 0.27
# Saving fake_images-0104.png
# Epoch [104/300],  d_loss: 0.8571, g_loss: 2.0422, D(x): 0.73, D(G(z)): 0.26
# Saving fake_images-0105.png
# Epoch [105/300],  d_loss: 1.1536, g_loss: 2.1667, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0106.png
# Epoch [106/300],  d_loss: 1.1618, g_loss: 1.6430, D(x): 0.62, D(G(z)): 0.31
# Saving fake_images-0107.png
# Epoch [107/300],  d_loss: 0.8398, g_loss: 1.8704, D(x): 0.78, D(G(z)): 0.33
# Saving fake_images-0108.png
# Epoch [108/300],  d_loss: 0.9329, g_loss: 1.4266, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0109.png
# Epoch [109/300],  d_loss: 0.4987, g_loss: 2.1708, D(x): 0.82, D(G(z)): 0.19
# Saving fake_images-0110.png
# Epoch [110/300],  d_loss: 0.8002, g_loss: 1.9833, D(x): 0.71, D(G(z)): 0.22
# Saving fake_images-0111.png
# Epoch [111/300],  d_loss: 0.8290, g_loss: 1.8267, D(x): 0.69, D(G(z)): 0.23
# Saving fake_images-0112.png
# Epoch [112/300],  d_loss: 1.0174, g_loss: 2.0714, D(x): 0.63, D(G(z)): 0.24
# Saving fake_images-0113.png
# Epoch [113/300],  d_loss: 1.0029, g_loss: 1.1635, D(x): 0.77, D(G(z)): 0.38
# Saving fake_images-0114.png
# Epoch [114/300],  d_loss: 0.7745, g_loss: 1.7707, D(x): 0.77, D(G(z)): 0.29
# Saving fake_images-0115.png
# Epoch [115/300],  d_loss: 0.9311, g_loss: 1.8541, D(x): 0.69, D(G(z)): 0.27
# Saving fake_images-0116.png
# Epoch [116/300],  d_loss: 0.9740, g_loss: 1.6334, D(x): 0.65, D(G(z)): 0.25
# Saving fake_images-0117.png
# Epoch [117/300],  d_loss: 0.8209, g_loss: 1.7146, D(x): 0.76, D(G(z)): 0.30
# Saving fake_images-0118.png
# Epoch [118/300],  d_loss: 0.9289, g_loss: 1.9600, D(x): 0.68, D(G(z)): 0.25
# Saving fake_images-0119.png
# Epoch [119/300],  d_loss: 0.7955, g_loss: 1.4652, D(x): 0.76, D(G(z)): 0.31
# Saving fake_images-0120.png
# Epoch [120/300],  d_loss: 0.5357, g_loss: 2.2264, D(x): 0.83, D(G(z)): 0.22
# Saving fake_images-0121.png
# Epoch [121/300],  d_loss: 0.9967, g_loss: 1.4654, D(x): 0.70, D(G(z)): 0.32
# Saving fake_images-0122.png
# Epoch [122/300],  d_loss: 0.9743, g_loss: 1.6138, D(x): 0.61, D(G(z)): 0.22
# Saving fake_images-0123.png
# Epoch [123/300],  d_loss: 0.8756, g_loss: 1.8622, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0124.png
# Epoch [124/300],  d_loss: 0.9019, g_loss: 1.9767, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0125.png
# Epoch [125/300],  d_loss: 1.0901, g_loss: 1.6156, D(x): 0.62, D(G(z)): 0.29
# Saving fake_images-0126.png
# Epoch [126/300],  d_loss: 1.0737, g_loss: 1.7171, D(x): 0.64, D(G(z)): 0.28
# Saving fake_images-0127.png
# Epoch [127/300],  d_loss: 0.6867, g_loss: 1.6089, D(x): 0.77, D(G(z)): 0.26
# Saving fake_images-0128.png
# Epoch [128/300],  d_loss: 0.8044, g_loss: 2.0898, D(x): 0.72, D(G(z)): 0.22
# Saving fake_images-0129.png
# Epoch [129/300],  d_loss: 0.9331, g_loss: 1.5096, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0130.png
# Epoch [130/300],  d_loss: 0.9062, g_loss: 1.5896, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0131.png
# Epoch [131/300],  d_loss: 0.9834, g_loss: 1.7874, D(x): 0.65, D(G(z)): 0.25
# Saving fake_images-0132.png
# Epoch [132/300],  d_loss: 1.0485, g_loss: 1.3303, D(x): 0.68, D(G(z)): 0.36
# Saving fake_images-0133.png
# Epoch [133/300],  d_loss: 0.9251, g_loss: 1.6524, D(x): 0.68, D(G(z)): 0.29
# Saving fake_images-0134.png
# Epoch [134/300],  d_loss: 1.1163, g_loss: 1.4333, D(x): 0.70, D(G(z)): 0.40
# Saving fake_images-0135.png
# Epoch [135/300],  d_loss: 0.8746, g_loss: 1.5818, D(x): 0.76, D(G(z)): 0.31
# Saving fake_images-0136.png
# Epoch [136/300],  d_loss: 0.8642, g_loss: 1.7405, D(x): 0.74, D(G(z)): 0.31
# Saving fake_images-0137.png
# Epoch [137/300],  d_loss: 0.6799, g_loss: 1.8069, D(x): 0.77, D(G(z)): 0.26
# Saving fake_images-0138.png
# Epoch [138/300],  d_loss: 0.7627, g_loss: 1.7751, D(x): 0.70, D(G(z)): 0.23
# Saving fake_images-0139.png
# Epoch [139/300],  d_loss: 0.6164, g_loss: 1.7399, D(x): 0.78, D(G(z)): 0.22
# Saving fake_images-0140.png
# Epoch [140/300],  d_loss: 0.8366, g_loss: 1.6949, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0141.png
# Epoch [141/300],  d_loss: 1.1548, g_loss: 1.9913, D(x): 0.59, D(G(z)): 0.28
# Saving fake_images-0142.png
# Epoch [142/300],  d_loss: 0.9371, g_loss: 1.7106, D(x): 0.70, D(G(z)): 0.29
# Saving fake_images-0143.png
# Epoch [143/300],  d_loss: 0.8289, g_loss: 1.8925, D(x): 0.79, D(G(z)): 0.31
# Saving fake_images-0144.png
# Epoch [144/300],  d_loss: 0.8472, g_loss: 1.8851, D(x): 0.73, D(G(z)): 0.24
# Saving fake_images-0145.png
# Epoch [145/300],  d_loss: 0.8976, g_loss: 1.2140, D(x): 0.73, D(G(z)): 0.33
# Saving fake_images-0146.png
# Epoch [146/300],  d_loss: 1.2125, g_loss: 1.5897, D(x): 0.61, D(G(z)): 0.35
# Saving fake_images-0147.png
# Epoch [147/300],  d_loss: 0.9192, g_loss: 1.6264, D(x): 0.72, D(G(z)): 0.31
# Saving fake_images-0148.png
# Epoch [148/300],  d_loss: 0.8511, g_loss: 1.6436, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0149.png
# Epoch [149/300],  d_loss: 0.9246, g_loss: 1.8395, D(x): 0.66, D(G(z)): 0.26
# Saving fake_images-0150.png
# Epoch [150/300],  d_loss: 0.7453, g_loss: 1.6891, D(x): 0.74, D(G(z)): 0.24
# Saving fake_images-0151.png
# Epoch [151/300],  d_loss: 0.8098, g_loss: 1.5905, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0152.png
# Epoch [152/300],  d_loss: 1.0768, g_loss: 1.6130, D(x): 0.69, D(G(z)): 0.34
# Saving fake_images-0153.png
# Epoch [153/300],  d_loss: 0.8834, g_loss: 1.8795, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0154.png
# Epoch [154/300],  d_loss: 0.7482, g_loss: 1.6460, D(x): 0.73, D(G(z)): 0.27
# Saving fake_images-0155.png
# Epoch [155/300],  d_loss: 0.7590, g_loss: 1.8384, D(x): 0.75, D(G(z)): 0.27
# Saving fake_images-0156.png
# Epoch [156/300],  d_loss: 0.8928, g_loss: 1.5041, D(x): 0.72, D(G(z)): 0.33
# Saving fake_images-0157.png
# Epoch [157/300],  d_loss: 0.9685, g_loss: 1.5587, D(x): 0.72, D(G(z)): 0.33
# Saving fake_images-0158.png
# Epoch [158/300],  d_loss: 0.7758, g_loss: 1.5246, D(x): 0.76, D(G(z)): 0.29
# Saving fake_images-0159.png
# Epoch [159/300],  d_loss: 0.8070, g_loss: 1.3485, D(x): 0.77, D(G(z)): 0.29
# Saving fake_images-0160.png
# Epoch [160/300],  d_loss: 0.8873, g_loss: 1.6047, D(x): 0.75, D(G(z)): 0.33
# Saving fake_images-0161.png
# Epoch [161/300],  d_loss: 0.8797, g_loss: 1.4878, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0162.png
# Epoch [162/300],  d_loss: 0.9154, g_loss: 1.6019, D(x): 0.68, D(G(z)): 0.29
# Saving fake_images-0163.png
# Epoch [163/300],  d_loss: 0.9228, g_loss: 1.3058, D(x): 0.73, D(G(z)): 0.35
# Saving fake_images-0164.png
# Epoch [164/300],  d_loss: 0.8167, g_loss: 1.9460, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0165.png
# Epoch [165/300],  d_loss: 1.1867, g_loss: 1.3932, D(x): 0.65, D(G(z)): 0.36
# Saving fake_images-0166.png
# Epoch [166/300],  d_loss: 1.0365, g_loss: 1.4926, D(x): 0.62, D(G(z)): 0.30
# Saving fake_images-0167.png
# Epoch [167/300],  d_loss: 0.9994, g_loss: 1.4112, D(x): 0.66, D(G(z)): 0.30
# Saving fake_images-0168.png
# Epoch [168/300],  d_loss: 0.7641, g_loss: 1.6517, D(x): 0.77, D(G(z)): 0.30
# Saving fake_images-0169.png
# Epoch [169/300],  d_loss: 1.0106, g_loss: 1.5554, D(x): 0.72, D(G(z)): 0.33
# Saving fake_images-0170.png
# Epoch [170/300],  d_loss: 0.9319, g_loss: 1.4063, D(x): 0.69, D(G(z)): 0.34
# Saving fake_images-0171.png
# Epoch [171/300],  d_loss: 0.8924, g_loss: 1.4821, D(x): 0.69, D(G(z)): 0.32
# Saving fake_images-0172.png
# Epoch [172/300],  d_loss: 0.8364, g_loss: 1.4496, D(x): 0.73, D(G(z)): 0.34
# Saving fake_images-0173.png
# Epoch [173/300],  d_loss: 1.0313, g_loss: 1.3507, D(x): 0.76, D(G(z)): 0.42
# Saving fake_images-0174.png
# Epoch [174/300],  d_loss: 1.1893, g_loss: 1.1443, D(x): 0.58, D(G(z)): 0.30
# Saving fake_images-0175.png
# Epoch [175/300],  d_loss: 1.1009, g_loss: 1.6458, D(x): 0.67, D(G(z)): 0.33
# Saving fake_images-0176.png
# Epoch [176/300],  d_loss: 0.8469, g_loss: 1.9478, D(x): 0.69, D(G(z)): 0.27
# Saving fake_images-0177.png
# Epoch [177/300],  d_loss: 0.9065, g_loss: 1.4631, D(x): 0.72, D(G(z)): 0.31
# Saving fake_images-0178.png
# Epoch [178/300],  d_loss: 0.7560, g_loss: 1.7332, D(x): 0.70, D(G(z)): 0.24
# Saving fake_images-0179.png
# Epoch [179/300],  d_loss: 1.3377, g_loss: 1.0992, D(x): 0.69, D(G(z)): 0.49
# Saving fake_images-0180.png
# Epoch [180/300],  d_loss: 0.8207, g_loss: 1.4459, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0181.png
# Epoch [181/300],  d_loss: 0.8416, g_loss: 1.5348, D(x): 0.69, D(G(z)): 0.27
# Saving fake_images-0182.png
# Epoch [182/300],  d_loss: 1.0426, g_loss: 1.1776, D(x): 0.69, D(G(z)): 0.35
# Saving fake_images-0183.png
# Epoch [183/300],  d_loss: 0.9489, g_loss: 1.2402, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0184.png
# Epoch [184/300],  d_loss: 1.0318, g_loss: 1.3679, D(x): 0.67, D(G(z)): 0.34
# Saving fake_images-0185.png
# Epoch [185/300],  d_loss: 1.0573, g_loss: 1.1923, D(x): 0.73, D(G(z)): 0.39
# Saving fake_images-0186.png
# Epoch [186/300],  d_loss: 1.0276, g_loss: 1.5412, D(x): 0.67, D(G(z)): 0.34
# Saving fake_images-0187.png
# Epoch [187/300],  d_loss: 1.1278, g_loss: 1.4703, D(x): 0.63, D(G(z)): 0.33
# Saving fake_images-0188.png
# Epoch [188/300],  d_loss: 1.0911, g_loss: 1.3404, D(x): 0.71, D(G(z)): 0.37
# Saving fake_images-0189.png
# Epoch [189/300],  d_loss: 0.9432, g_loss: 1.7817, D(x): 0.69, D(G(z)): 0.30
# Saving fake_images-0190.png
# Epoch [190/300],  d_loss: 1.0482, g_loss: 1.4015, D(x): 0.70, D(G(z)): 0.37
# Saving fake_images-0191.png
# Epoch [191/300],  d_loss: 0.9722, g_loss: 1.4368, D(x): 0.67, D(G(z)): 0.31
# Saving fake_images-0192.png
# Epoch [192/300],  d_loss: 0.8546, g_loss: 1.3508, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0193.png
# Epoch [193/300],  d_loss: 1.3953, g_loss: 1.5082, D(x): 0.54, D(G(z)): 0.24
# Saving fake_images-0194.png
# Epoch [194/300],  d_loss: 1.0346, g_loss: 1.2009, D(x): 0.70, D(G(z)): 0.37
# Saving fake_images-0195.png
# Epoch [195/300],  d_loss: 0.9078, g_loss: 1.3329, D(x): 0.72, D(G(z)): 0.34
# Saving fake_images-0196.png
# Epoch [196/300],  d_loss: 0.9634, g_loss: 1.3063, D(x): 0.67, D(G(z)): 0.31
# Saving fake_images-0197.png
# Epoch [197/300],  d_loss: 0.7610, g_loss: 1.5132, D(x): 0.72, D(G(z)): 0.26
# Saving fake_images-0198.png
# Epoch [198/300],  d_loss: 0.8890, g_loss: 1.6189, D(x): 0.67, D(G(z)): 0.28
# Saving fake_images-0199.png
# Epoch [199/300],  d_loss: 1.0041, g_loss: 1.5386, D(x): 0.65, D(G(z)): 0.30
# Saving fake_images-0200.png
# Epoch [200/300],  d_loss: 0.9404, g_loss: 1.4698, D(x): 0.69, D(G(z)): 0.31
# Saving fake_images-0201.png
# Epoch [201/300],  d_loss: 1.0146, g_loss: 1.3406, D(x): 0.70, D(G(z)): 0.37
# Saving fake_images-0202.png
# Epoch [202/300],  d_loss: 0.9826, g_loss: 1.5685, D(x): 0.66, D(G(z)): 0.32
# Saving fake_images-0203.png
# Epoch [203/300],  d_loss: 0.8737, g_loss: 1.4861, D(x): 0.74, D(G(z)): 0.34
# Saving fake_images-0204.png
# Epoch [204/300],  d_loss: 0.9905, g_loss: 1.7066, D(x): 0.72, D(G(z)): 0.38
# Saving fake_images-0205.png
# Epoch [205/300],  d_loss: 0.9383, g_loss: 1.7583, D(x): 0.65, D(G(z)): 0.25
# Saving fake_images-0206.png
# Epoch [206/300],  d_loss: 1.0712, g_loss: 1.4002, D(x): 0.65, D(G(z)): 0.36
# Saving fake_images-0207.png
# Epoch [207/300],  d_loss: 1.1358, g_loss: 1.3228, D(x): 0.66, D(G(z)): 0.40
# Saving fake_images-0208.png
# Epoch [208/300],  d_loss: 0.9593, g_loss: 1.4027, D(x): 0.68, D(G(z)): 0.32
# Saving fake_images-0209.png
# Epoch [209/300],  d_loss: 0.8473, g_loss: 1.6009, D(x): 0.77, D(G(z)): 0.35
# Saving fake_images-0210.png
# Epoch [210/300],  d_loss: 1.0076, g_loss: 1.3589, D(x): 0.71, D(G(z)): 0.37
# Saving fake_images-0211.png
# Epoch [211/300],  d_loss: 0.8614, g_loss: 1.4826, D(x): 0.68, D(G(z)): 0.28
# Saving fake_images-0212.png
# Epoch [212/300],  d_loss: 0.7893, g_loss: 1.7638, D(x): 0.71, D(G(z)): 0.26
# Saving fake_images-0213.png
# Epoch [213/300],  d_loss: 1.0123, g_loss: 1.3997, D(x): 0.59, D(G(z)): 0.28
# Saving fake_images-0214.png
# Epoch [214/300],  d_loss: 1.1971, g_loss: 1.1771, D(x): 0.67, D(G(z)): 0.42
# Saving fake_images-0215.png
# Epoch [215/300],  d_loss: 0.8438, g_loss: 1.4568, D(x): 0.71, D(G(z)): 0.28
# Saving fake_images-0216.png
# Epoch [216/300],  d_loss: 0.8845, g_loss: 1.4427, D(x): 0.70, D(G(z)): 0.33
# Saving fake_images-0217.png
# Epoch [217/300],  d_loss: 0.9889, g_loss: 1.4701, D(x): 0.66, D(G(z)): 0.33
# Saving fake_images-0218.png
# Epoch [218/300],  d_loss: 0.9930, g_loss: 1.5198, D(x): 0.69, D(G(z)): 0.35
# Saving fake_images-0219.png
# Epoch [219/300],  d_loss: 0.8848, g_loss: 1.4689, D(x): 0.68, D(G(z)): 0.28
# Saving fake_images-0220.png
# Epoch [220/300],  d_loss: 0.8348, g_loss: 1.8699, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0221.png
# Epoch [221/300],  d_loss: 0.9264, g_loss: 1.4977, D(x): 0.70, D(G(z)): 0.30
# Saving fake_images-0222.png
# Epoch [222/300],  d_loss: 0.9156, g_loss: 1.4241, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0223.png
# Epoch [223/300],  d_loss: 0.9805, g_loss: 1.2190, D(x): 0.69, D(G(z)): 0.37
# Saving fake_images-0224.png
# Epoch [224/300],  d_loss: 1.0183, g_loss: 1.3214, D(x): 0.67, D(G(z)): 0.36
# Saving fake_images-0225.png
# Epoch [225/300],  d_loss: 0.9448, g_loss: 1.4943, D(x): 0.69, D(G(z)): 0.33
# Saving fake_images-0226.png
# Epoch [226/300],  d_loss: 1.1231, g_loss: 1.1803, D(x): 0.72, D(G(z)): 0.44
# Saving fake_images-0227.png
# Epoch [227/300],  d_loss: 0.8561, g_loss: 1.7096, D(x): 0.67, D(G(z)): 0.27
# Saving fake_images-0228.png
# Epoch [228/300],  d_loss: 1.2041, g_loss: 1.3507, D(x): 0.55, D(G(z)): 0.32
# Saving fake_images-0229.png
# Epoch [229/300],  d_loss: 1.3730, g_loss: 1.2171, D(x): 0.66, D(G(z)): 0.44
# Saving fake_images-0230.png
# Epoch [230/300],  d_loss: 1.0325, g_loss: 1.4667, D(x): 0.65, D(G(z)): 0.33
# Saving fake_images-0231.png
# Epoch [231/300],  d_loss: 0.9999, g_loss: 1.3040, D(x): 0.70, D(G(z)): 0.38
# Saving fake_images-0232.png
# Epoch [232/300],  d_loss: 0.8612, g_loss: 1.4589, D(x): 0.67, D(G(z)): 0.28
# Saving fake_images-0233.png
# Epoch [233/300],  d_loss: 0.9960, g_loss: 1.5459, D(x): 0.67, D(G(z)): 0.32
# Saving fake_images-0234.png
# Epoch [234/300],  d_loss: 1.1367, g_loss: 1.1905, D(x): 0.64, D(G(z)): 0.36
# Saving fake_images-0235.png
# Epoch [235/300],  d_loss: 0.9871, g_loss: 1.3083, D(x): 0.68, D(G(z)): 0.35
# Saving fake_images-0236.png
# Epoch [236/300],  d_loss: 1.1572, g_loss: 1.1961, D(x): 0.63, D(G(z)): 0.39
# Saving fake_images-0237.png
# Epoch [237/300],  d_loss: 1.0761, g_loss: 1.3120, D(x): 0.62, D(G(z)): 0.32
# Saving fake_images-0238.png
# Epoch [238/300],  d_loss: 1.0923, g_loss: 1.2738, D(x): 0.63, D(G(z)): 0.32
# Saving fake_images-0239.png
# Epoch [239/300],  d_loss: 0.9079, g_loss: 1.3605, D(x): 0.64, D(G(z)): 0.25
# Saving fake_images-0240.png
# Epoch [240/300],  d_loss: 0.8483, g_loss: 1.4823, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0241.png
# Epoch [241/300],  d_loss: 0.9624, g_loss: 1.6279, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0242.png
# Epoch [242/300],  d_loss: 1.0374, g_loss: 1.1583, D(x): 0.66, D(G(z)): 0.34
# Saving fake_images-0243.png
# Epoch [243/300],  d_loss: 1.0344, g_loss: 1.3547, D(x): 0.67, D(G(z)): 0.34
# Saving fake_images-0244.png
# Epoch [244/300],  d_loss: 0.9405, g_loss: 1.3216, D(x): 0.65, D(G(z)): 0.29
# Saving fake_images-0245.png
# Epoch [245/300],  d_loss: 1.0663, g_loss: 1.3120, D(x): 0.69, D(G(z)): 0.40
# Saving fake_images-0246.png
# Epoch [246/300],  d_loss: 0.9908, g_loss: 1.4119, D(x): 0.67, D(G(z)): 0.34
# Saving fake_images-0247.png
# Epoch [247/300],  d_loss: 1.0107, g_loss: 1.5108, D(x): 0.70, D(G(z)): 0.37
# Saving fake_images-0248.png
# Epoch [248/300],  d_loss: 1.0398, g_loss: 1.4562, D(x): 0.65, D(G(z)): 0.33
# Saving fake_images-0249.png
# Epoch [249/300],  d_loss: 1.0421, g_loss: 1.2088, D(x): 0.69, D(G(z)): 0.39
# Saving fake_images-0250.png
# Epoch [250/300],  d_loss: 0.8804, g_loss: 1.8925, D(x): 0.67, D(G(z)): 0.28
# Saving fake_images-0251.png
# Epoch [251/300],  d_loss: 0.9932, g_loss: 1.2918, D(x): 0.66, D(G(z)): 0.35
# Saving fake_images-0252.png
# Epoch [252/300],  d_loss: 1.0193, g_loss: 1.4723, D(x): 0.62, D(G(z)): 0.29
# Saving fake_images-0253.png
# Epoch [253/300],  d_loss: 1.2418, g_loss: 1.3946, D(x): 0.60, D(G(z)): 0.38
# Saving fake_images-0254.png
# Epoch [254/300],  d_loss: 0.9972, g_loss: 1.5355, D(x): 0.63, D(G(z)): 0.30
# Saving fake_images-0255.png
# Epoch [255/300],  d_loss: 1.2157, g_loss: 1.3139, D(x): 0.61, D(G(z)): 0.38
# Saving fake_images-0256.png
# Epoch [256/300],  d_loss: 1.2120, g_loss: 1.1321, D(x): 0.61, D(G(z)): 0.36
# Saving fake_images-0257.png
# Epoch [257/300],  d_loss: 0.7807, g_loss: 1.5446, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0258.png
# Epoch [258/300],  d_loss: 0.9784, g_loss: 1.3029, D(x): 0.70, D(G(z)): 0.38
# Saving fake_images-0259.png
# Epoch [259/300],  d_loss: 1.0795, g_loss: 1.3993, D(x): 0.65, D(G(z)): 0.36
# Saving fake_images-0260.png
# Epoch [260/300],  d_loss: 1.0189, g_loss: 1.1216, D(x): 0.70, D(G(z)): 0.39
# Saving fake_images-0261.png
# Epoch [261/300],  d_loss: 1.0582, g_loss: 1.5257, D(x): 0.66, D(G(z)): 0.35
# Saving fake_images-0262.png
# Epoch [262/300],  d_loss: 1.0113, g_loss: 1.5792, D(x): 0.67, D(G(z)): 0.33
# Saving fake_images-0263.png
# Epoch [263/300],  d_loss: 1.0619, g_loss: 1.8222, D(x): 0.59, D(G(z)): 0.29
# Saving fake_images-0264.png
# Epoch [264/300],  d_loss: 1.0909, g_loss: 1.2435, D(x): 0.61, D(G(z)): 0.35
# Saving fake_images-0265.png
# Epoch [265/300],  d_loss: 0.9228, g_loss: 1.2919, D(x): 0.71, D(G(z)): 0.35
# Saving fake_images-0266.png
# Epoch [266/300],  d_loss: 0.9368, g_loss: 1.4961, D(x): 0.63, D(G(z)): 0.27
# Saving fake_images-0267.png
# Epoch [267/300],  d_loss: 1.0625, g_loss: 1.5124, D(x): 0.64, D(G(z)): 0.33
# Saving fake_images-0268.png
# Epoch [268/300],  d_loss: 1.1481, g_loss: 1.2454, D(x): 0.63, D(G(z)): 0.37
# Saving fake_images-0269.png
# Epoch [269/300],  d_loss: 1.0165, g_loss: 1.4639, D(x): 0.69, D(G(z)): 0.35
# Saving fake_images-0270.png
# Epoch [270/300],  d_loss: 1.0129, g_loss: 1.4670, D(x): 0.61, D(G(z)): 0.29
# Saving fake_images-0271.png
# Epoch [271/300],  d_loss: 1.1017, g_loss: 1.1203, D(x): 0.68, D(G(z)): 0.40
# Saving fake_images-0272.png
# Epoch [272/300],  d_loss: 1.1987, g_loss: 1.2956, D(x): 0.58, D(G(z)): 0.36
# Saving fake_images-0273.png
# Epoch [273/300],  d_loss: 1.2246, g_loss: 1.4825, D(x): 0.58, D(G(z)): 0.35
# Saving fake_images-0274.png
# Epoch [274/300],  d_loss: 0.9946, g_loss: 1.4092, D(x): 0.67, D(G(z)): 0.35
# Saving fake_images-0275.png
# Epoch [275/300],  d_loss: 1.2498, g_loss: 1.0495, D(x): 0.63, D(G(z)): 0.43
# Saving fake_images-0276.png
# Epoch [276/300],  d_loss: 0.9916, g_loss: 1.3790, D(x): 0.71, D(G(z)): 0.37
# Saving fake_images-0277.png
# Epoch [277/300],  d_loss: 1.0520, g_loss: 1.2512, D(x): 0.65, D(G(z)): 0.37
# Saving fake_images-0278.png
# Epoch [278/300],  d_loss: 1.2437, g_loss: 1.1739, D(x): 0.60, D(G(z)): 0.41
# Saving fake_images-0279.png
# Epoch [279/300],  d_loss: 1.0491, g_loss: 1.3657, D(x): 0.65, D(G(z)): 0.35
# Saving fake_images-0280.png
# Epoch [280/300],  d_loss: 0.9155, g_loss: 1.4701, D(x): 0.70, D(G(z)): 0.32
# Saving fake_images-0281.png
# Epoch [281/300],  d_loss: 1.0614, g_loss: 1.2504, D(x): 0.66, D(G(z)): 0.35
# Saving fake_images-0282.png
# Epoch [282/300],  d_loss: 1.0725, g_loss: 1.4560, D(x): 0.62, D(G(z)): 0.33
# Saving fake_images-0283.png
# Epoch [283/300],  d_loss: 1.0673, g_loss: 1.6311, D(x): 0.65, D(G(z)): 0.37
# Saving fake_images-0284.png
# Epoch [284/300],  d_loss: 0.9297, g_loss: 1.3796, D(x): 0.69, D(G(z)): 0.30
# Saving fake_images-0285.png
# Epoch [285/300],  d_loss: 1.1305, g_loss: 1.3247, D(x): 0.64, D(G(z)): 0.40
# Saving fake_images-0286.png
# Epoch [286/300],  d_loss: 0.9542, g_loss: 1.3283, D(x): 0.72, D(G(z)): 0.38
# Saving fake_images-0287.png
# Epoch [287/300],  d_loss: 1.0319, g_loss: 1.3103, D(x): 0.67, D(G(z)): 0.36
# Saving fake_images-0288.png
# Epoch [288/300],  d_loss: 0.9652, g_loss: 1.3547, D(x): 0.61, D(G(z)): 0.28
# Saving fake_images-0289.png
# Epoch [289/300],  d_loss: 1.0259, g_loss: 1.3235, D(x): 0.67, D(G(z)): 0.35
# Saving fake_images-0290.png
# Epoch [290/300],  d_loss: 1.3143, g_loss: 1.1100, D(x): 0.59, D(G(z)): 0.41
# Saving fake_images-0291.png
# Epoch [291/300],  d_loss: 0.8929, g_loss: 1.2158, D(x): 0.68, D(G(z)): 0.31
# Saving fake_images-0292.png
# Epoch [292/300],  d_loss: 0.9601, g_loss: 1.1500, D(x): 0.70, D(G(z)): 0.33
# Saving fake_images-0293.png
# Epoch [293/300],  d_loss: 1.0060, g_loss: 1.5978, D(x): 0.67, D(G(z)): 0.36
# Saving fake_images-0294.png
# Epoch [294/300],  d_loss: 1.0458, g_loss: 1.2688, D(x): 0.61, D(G(z)): 0.31
# Saving fake_images-0295.png
# Epoch [295/300],  d_loss: 0.8683, g_loss: 1.7113, D(x): 0.68, D(G(z)): 0.27
# Saving fake_images-0296.png
# Epoch [296/300],  d_loss: 0.6395, g_loss: 1.6054, D(x): 0.77, D(G(z)): 0.25
# Saving fake_images-0297.png
# Epoch [297/300],  d_loss: 1.1102, g_loss: 1.0308, D(x): 0.61, D(G(z)): 0.35
# Saving fake_images-0298.png
# Epoch [298/300],  d_loss: 0.9134, g_loss: 1.3563, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0299.png
# Epoch [299/300],  d_loss: 1.1320, g_loss: 1.6260, D(x): 0.66, D(G(z)): 0.39
# Saving fake_images-0300.png
# CPU times: user 1h 22min 21s, sys: 7min 6s, total: 1h 29min 27s
# Wall time: 1h 17min 22s

# %%
plt.ylim([0,4])
plt.plot(d_losses)
plt.plot(g_losses)

# %%
plt.ylim([0,1])
plt.plot(fake_scores)
plt.plot(real_scores)
